# %% [markdown]
# # Format the dataset

# %%
import os
import pandas as pd
from collections import defaultdict

text = []
counts = defaultdict(int)
# Iterate through the dataset directory which contains seperate datasets for each topic in .csv files
for dataset_dir in os.listdir('/kaggle/input/opentriviaqa-database'):
    
    dataset_fulldir = os.path.join('/kaggle/input/opentriviaqa-database', dataset_dir)
    # open each dataset
    topic_df = pd.read_csv(dataset_fulldir)
    
    topic = ' '.join(dataset_dir[9:-4].split('-'))
    # normalize and merge some topic names
    topic_map = {'religion faith': 'religion', 'science technology': 'science', 'newest': 'general', 'world': 'general', 'entertainment': 'television',
                 'rated': 'general', 'hobbies': 'general', 'for kids': 'general', 'people': 'celebrities', 'humanities': 'linguistics'}
    if topic in topic_map:
        topic = topic_map[topic]
        
    # count the questions for each topic
    c = 0
    # Filter and collect rows for each topic
    for index, row in topic_df.iterrows():
        # filter the 'All of them' and 'None of them' answers
        if all(s not in str(row['Correct']).lower() for s in ['all', 'none']) and pd.notna(row['Correct']):

            # normalize the question: the original dataset consists of questions with 4 possible choices and the questions may be framed tailored to that
            # in this project, the user provides an arbitrary answer 
            # replace 'Which of these' with 'Which'
            question = row['Questions'].replace('Which of these', 'Which')[:-1]  
            answer = row['Correct']
            # another normalization: Yes becomes True, No becomes False
            answer_map = {'yes': 'True', 'no': 'False'}
            if answer.lower() in answer_map:
                answer = answer_map[answer.lower()]
 
            text.append(f"{topic}\n{question} ({answer})")
            c += 1
            
    counts[topic] += c

# store the topics as labels alongside with the full text to be able to group them later
text_df = pd.DataFrame(text, columns=['text']).drop_duplicates()
# shuffle
text_df = text_df.sample(frac=1, random_state=42).reset_index(drop=True)

print(counts, '\n')
print(f"Sample text:\n\n{text_df['text'].sample(frac=1/len(text_df)).iloc[-1]}")
# Out:
# defaultdict(<class 'int'>, {'television': 5367, 'literature': 1233, 'general': 14754, 'religion': 621, 'geography': 802, 'history': 1605, 'movies': 4143, 'video games': 582, 'animals': 1260, 'brain teasers': 207, 'sports': 2757, 'music': 5367, 'science': 2366, 'celebrities': 5725, 'linguistics': 1062})
#
# Sample text:
#
# general
# In order to extract superior espresso consistently, you must precisely control many factors. Which of the following is not one of those factors? (Fat content of milk you use)

# %% [markdown]
# # Prepare the data for training

# %% [markdown]
# Load the tokenizer of the model we're going to fine tune: GPT-2 Medium (a more advanced variation of original GPT-2)

# %%
from transformers import AutoTokenizer

model_name = "gpt2-medium"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# Get familiar with word counts for setting an optimal max sequence length parameter for padding and trunctation

# %%
import numpy as np

word_counts = text_df['text'].apply(lambda x: len(x.split(' ')))

# while the number of words is not strictly equal to the number of tokens,
# its rougly proportional, so we can use it as a reasonable estimate
print("Percentile - Value of percentile pairs\n")
for q in np.arange(0.9, 1.01, 0.01):
    print(f"{q}: {word_counts.quantile(q)}")
# Out:
# Percentile - Value of percentile pairs
#
# 0.9: 30.0
# 0.91: 31.0
# 0.92: 33.0
# 0.93: 34.0
# 0.9400000000000001: 35.0
# 0.9500000000000001: 37.0
# 0.9600000000000001: 40.0
# 0.9700000000000001: 43.0
# 0.9800000000000001: 47.30000000000291
# 0.9900000000000001: 56.0
# 1.0: 139.0

# %% [markdown]
# # The sequences longer than 50 tokens are treated as outliers and excluded entirely to reduce noise and simplify the process

# %%
from datasets import Dataset

max_tokens = 50
# make a Hugging Face Dataset out of Pandas DataFrame
dataset = Dataset.from_pandas(text_df)

# tokenize and filter the dataset
def _filter(X):
    # the dataset itself isnt tokenized here yet, we simply use the tokenized form to filter out the outliers
    X_tokenized = tokenizer(X["text"], truncation=False, padding=False)
    # return boolean values which are used by filter() to drop the instances that dont meet the criteria (are too long)
    return len(X_tokenized['input_ids']) <= max_tokens

def tokenize_labelize(X):
    # the shorter sequences are padded to reach max_tokens
    # truncation=True is redundant here but is still included for best practices
    tokenized = tokenizer(X["text"], truncation=True, padding="max_length", max_length=max_tokens)
    # clone the tokens as labels to make the model train to predict the next token based on previous token(s) 
    tokenized["labels"] = tokenized["input_ids"]
    return tokenized

# tokenize the filtered dataset in batches
dataset_tokenized = dataset.filter(_filter).map(tokenize_labelize, batched=True)
# Out:
# Filter:   0%|          | 0/47586 [00:00<?, ? examples/s]
# Map:   0%|          | 0/45013 [00:00<?, ? examples/s]

# %% [markdown]
# # Load GPT-2 for fine-tuning on our specific task: generation of topic relevant question-answer pairs

# %%
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")
# Out:
# 2025-04-19 12:51:19.657076: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745067080.048072      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745067080.158348      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
import random
from transformers import Trainer, TrainingArguments, TrainerCallback, EarlyStoppingCallback

unique_topics = list(counts.keys())

class TextGenerationCallback(TrainerCallback):
    '''Custom callback: during training, generate text in specified intervals'''
    def __init__(self, model, tokenizer, trigger_freq, k=1):
        self.model = model
        self.tokenizer = tokenizer
        self.trigger_freq = trigger_freq
        self.k = k
    
    def on_step_end(self, args, state, control, **kwargs):
        if not int(state.global_step+1) % self.trigger_freq:
            print(f"Generated text on step {int(state.global_step+1)}:\n")
            for _ in range(self.k):
                # tokenize the prompt and pass it to the gpu
                prompt_text = f"{random.choice(unique_topics)}\n"
                prompt_tokenized = self.tokenizer(prompt_text, return_tensors = 'pt').to(self.model.device)
                # generate tokens
                output = self.model.generate(
                    prompt_tokenized['input_ids'],
                    attention_mask = prompt_tokenized["attention_mask"],
                    max_length=50,
                    do_sample=True,
                    temperature=0.3,  
                    top_k=5,         
                    top_p=0.9,       
                    repetition_penalty=1.2,
                    pad_token_id=50256
                )
                # decode the generated tokens into text
                generated_text = self.tokenizer.decode(output[0], skip_special_tokens=True)
                print(f"\n{generated_text}\n")
    
            print()


class LearningRateCallback(TrainerCallback):
    '''Custom callback: print the learning rate at the start of each epoch'''
    def on_epoch_begin(self, args, state, control, **kwargs):
        # access the optimizer from the trainer
        optimizer = kwargs["optimizer"]
        # get the current learning rate from the optimizer
        current_lr = optimizer.param_groups[0]["lr"]
        print(f"Epoch {int(state.epoch)+1}\nLearning Rate: {current_lr}")


# define training arguments
training_args = TrainingArguments(
    output_dir = './training_results', # Directory to save the model
    overwrite_output_dir = True,
    learning_rate = 5e-5,
    lr_scheduler_type = 'linear', # the learning rate increases to its max value (warms up) then starts to decrease 
    warmup_steps = 3000, 
    per_device_train_batch_size = 64, # batch size passed to each gpu
    num_train_epochs = 10, # number of epochs
    save_strategy = 'epoch', # save a checkpoint after each epoch
    save_total_limit = 5, # limit the number of saved checkpoints
    fp16 = True, # use mixed precision for more speed
    report_to=[], # turn off logging 
)


lr_tracker = LearningRateCallback()
gen_callback = TextGenerationCallback(model=model, tokenizer=tokenizer, trigger_freq=50, k=3)
# initialize the trainer
trainer = Trainer(
    model = model, 
    args = training_args,
    # it was decided to train the model on the full dataset and use human evaluation instead of a validation set with loss computation
    train_dataset = dataset_tokenized,
    processing_class = tokenizer,
    callbacks = [lr_tracker, gen_callback]
)

# start fine tuning
trainer.train()

# save the fine tuned model
model.save_pretrained("./distilgpt2-finetuned")
tokenizer.save_pretrained("./dstilgpt2-finetuned")
# Out:
# Epoch 1
# Learning Rate: 0.0
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='3521' max='7040' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3521/7040 46:54 < 46:54, 1.25 it/s, Epoch 5/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.654300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.482800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.426500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.375900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.317900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.263000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.214500</td>
#     </tr>
#   </tbody>
# </table><p>
# Generated text on step 50:
#
#
# sports
# The first thing I did after my return was to the gym and do some stretching. It's a great way of getting your body ready for training, but it can also be very dangerous if you don't get enough rest in between workouts.
#
#
# literature
#
# The following is a list of the most common words used in this article:
#
#
# television
#
#
# , the first of its kind in a new series. The show is based on an original story by writer and director/producer David Fincher (The Hangover , A Beautiful Mind ) who has written for such shows as
#
#
# Generated text on step 100:
#
#
# music
#
#
#
# geography
# The following is a list of the most common and rare items in Fallout 3.
#
#
# religion
#
#
#
# Generated text on step 150:
#
#
# religion
#
#
#
# general
#
#
#
# music
#
#
#
# Generated text on step 200:
#
#
# literature
# The story of the first novel by Ernest Hemingway is about a young boy named William, who was born in 1854. He has been raised to be an honest man and he becomes involved with politics when his father dies at age
#
#
# sports
# What is the name of the first album by The Beatles? (The White Album)
#
#
# music
# What is the name of a song by The Who that was released in 1975? (The Rolling Stones' "I Wanna Be Your Man")
#
#
# Generated text on step 250:
#
#
# linguistics
# What is the name of this famous French wine? (Chardonnay)
#
#
# animals
# What species of bird is the most common in North America? (American Blackbird)
#
#
# literature
# What is the name of the character in The Lord Of Rings trilogy? (The Ring)
#
#
# Generated text on step 300:
#
#
# brain teasers
# What is the name of this fictional character in The Wizarding World? (Draco Malfoy)
#
#
# movies
# What is the name of this character in The Godfather? (The Italian mobster)
#
#
# television
# What is the name of the fictional character from the TV show Friends? (Drew)
#
#
# Generated text on step 350:
#
#
# television
# In the TV series The X-Files, which is a spinoff of another show? (The X Files)
#
#
# literature
# What is the name of a character in The Lord Of Rings trilogy? (The Ring)
#
#
# religion
# The name of the god is derived from a Greek word meaning "gods". (Apollo)
#
#
# Generated text on step 400:
#
#
# religion
# What is the name of a character in The Lord Of The Rings? (The King)
#
#
# animals
# What is the name of a species in which this animal lives? (The lion)
#
#
# brain teasers
# What is the name of a character in The Lord Of War? (The Black Knight)
#
#
# Generated text on step 450:
#
#
# television
# What is the name of a character in The Simpsons who has an obsession with dinosaurs? (Dino)
#
#
# animals
# What is the name of this species in Australia? (Mongo)
#
#
# religion
# What is the name of a famous American author who wrote about this subject? (William Faulkner)
#
#
# Generated text on step 500:
#
#
# music
# What song is the title of which album by this band? (The Last Waltz)
#
#
# sports
# The first World Series was played in the United States. (False)
#
#
# music
# What song by this band is not a hit? (I Will Always Love You)
#
#
# Generated text on step 550:
#
#
# animals
# What is the name of a species that lives in South America? (Piglet)
#
#
# movies
# What is the name of a character in which The Godfather movies was filmed? (The King)
#
#
# religion
# What is the name of a famous ancient Greek philosopher, who wrote about this topic? (Plato)
#
#
# Generated text on step 600:
#
#
# video games
# In the game Final Fantasy VII, what is a type of magic item? (A ring)
#
#
# brain teasers
# What is the name of a character in The Wizarding World Of Harry Potter? (Sirius Black)
#
#
# geography
# What is the name of a famous French writer, who wrote The Last Temptation and A Thousand Years? (Jean-Jacques Rousseau)
#
#
# Generated text on step 650:
#
#
# science
# What is the name of a type-1 diabetes drug that was used to treat this disease? (Syracryl)
#
#
# celebrities
# In the movie The Godfather, which of these characters is not a member or close friend to John Gotti? (John Cazale)
#
#
# television
# What was the name of a character on The Office? (Mr. Hester)
#
#
# Generated text on step 700:
#
#
# science
# What is the name of a fictional character in which Harry Potter books? (Snape)
#
#
# science
# What is the name of a molecule that has been used to treat epilepsy? (epilepsy)
#
#
# general
# What is the name of a character in which Harry Potter and The Deathly Hallows: Part 2 takes place? (Dumbledore)
#
#
# Epoch 2
# Learning Rate: 1.1616666666666667e-05
# Generated text on step 750:
#
#
# music
# What song by the Beatles was not included in their album Sgt. Pepper? (The End of The World)
#
#
# movies
# What is the name of Michael Jackson's ex-girlfriend in The Truth About Love? (Mia Farrow)
#
#
# history
# The first recorded use of the term was in 1825 by a French diplomat. (False)
#
#
# Generated text on step 800:
#
#
# geography
# This island is located in the Pacific Ocean. (Hawaii)
#
#
# general
# What is the name of this famous French writer, who was a leading figure in literary criticism? (Jacques Derrida)
#
#
# religion
# In the Bible, God is referred to as a god of war. (False)
#
#
# Generated text on step 850:
#
#
# science
# The term for this type of cancer is melanoma. (Melanocortin)
#
#
# history
# The first atomic bomb was detonated on August 6, 1945. (True)
#
#
# literature
# Which of the following is not a fictional character in The Lord Of War series? (The King)
#
#
# Generated text on step 900:
#
#
# literature
# What is the name of a character in which Harry Potter and his friends are characters? (The Boy Who Lived)
#
#
# movies
# What is the name of Michael Caine character in The Godfather? (Marlon)
#
#
# literature
# In the novel The Wind in a Bottle, which of these characters is not named? (The protagonist)
#
#
# Generated text on step 950:
#
#
# history
# In the movie The Wizard of Oz, what was Dorothy Galezs favorite color? (Blue)
#
#
# celebrities
# In the movie The Graduate, what was a character called? (A college professor)
#
#
# history
# The first atomic bomb was detonated on August 6, 1945. (False)
#
#
# Generated text on step 1000:
#
#
# brain teasers
# What is the name of a character in The Wizard Of Oz who has an affinity for chocolate? (Mabel)
#
#
# geography
# What is the largest city in India? (New Delhi)
#
#
# science
# What is the meaning of a word that means to be in control? (Control)
#
#
# Generated text on step 1050:
#
#
# television
# What is the name of a character in The Simpsons who has an obsession with Homer? (The Bartender)
#
#
# music
# What song by The Beatles was the #1 U.S.? (Help!)
#
#
# video games
# What is the name of a character in Super Smash Bros. Melee? (The Big Boss)
#
#
# Generated text on step 1100:
#
#
# animals
# What is the largest mammal on Earth? (Hippopotamus)
#
#
# literature
# In which of the following works does this quote appear: (The only thing that is true about life, it seems to me)
#
#
# linguistics
# Which of the following is not a type in which there are no pairs? (A)
#
#
# Generated text on step 1150:
#
#
# movies
# In the movie The Crow, what was a name given to one of these characters? (The Black Dog)
#
#
# literature
# What is the name of a character in which Harry Potter and his friends meet at Hogwarts? (Sirius Black)
#
#
# animals
# What is the largest species of cat in Australia? (Panthera leo)
#
#
# Generated text on step 1200:
#
#
# geography
# The largest island in the world is located on this continent. (North America)
#
#
# celebrities
# What was the name of her first husband? (John)
#
#
# sports
# What was the name of a famous American actor who played an old-timey  gambler in which movie? (The Great Gatsby)
#
#
# Generated text on step 1250:
#
#
# brain teasers
# What is the name of a character in The Princess Bride? (The Queen)
#
#
# linguistics
# The word for the female form of this animal is called a wombat. (Cat)
#
#
# celebrities
# What is the name of a character in which movie, directed by John Ford? (The Man Who Killed Mr. Lincoln)
#
#
# Generated text on step 1300:
#
#
# history
# In which of the following movies did Tom Cruise play a character who was not from his own family? (The Pursuit Of Happiness)
#
#
# brain teasers
# What is the name of a character in which Harry Potter and Hermione Granger book? (Dumbledore)
#
#
# religion
# What is the name of a famous Jewish mystic who lived in Jerusalem? (Zechariah)
#
#
# Generated text on step 1350:
#
#
# music
# What is the name of a song by The Rolling Stones? (The Way Youre Making Me Feel)
#
#
# literature
# In the novel The Grapes of Wrath, what is a man called? (A gentleman)
#
#
# television
# What was the name of a character in The Brady Bunch? (The Boss)
#
#
# Generated text on step 1400:
#
#
# sports
# Which of the following is not a member's first name? (Babe Ruth)
#
#
# religion
# What is the name of a Jewish woman who was burned at her wedding in Jerusalem? (Ava)
#
#
# science
# What is the name of a type that can be found in many plants? (Cabbage)
#
#
# Epoch 3
# Learning Rate: 2.3350000000000002e-05
# Generated text on step 1450:
#
#
# geography
# What is the capital of South Africa? (Natal)
#
#
# literature
# In the book The Wizard of Oz, what is Dorothys name? (Dorothy)
#
#
# celebrities
# What is the name of John Wayne, Jr.s first movie? (The Last Crusade)
#
#
# Generated text on step 1500:
#
#
# religion
# In the Book of Revelation, what is referred to as a man who was born in Bethlehem? (A king)
#
#
# celebrities
# What was the name of John Waynes first movie? (The Man with a Golden Gun)
#
#
# literature
# What is the name of Harry Potter and his friends, who are in love with Hermione? (The Order)
#
#
# Generated text on step 1550:
#
#
# movies
# In the movie The Crow, what is a crowbar used for? (A lock)
#
#
# geography
# What is the name of a river in which there are no lakes? (The River Nile)
#
#
# video games
# In the game Super Smash Bros. Brawl, what is your character called? (Yoshi)
#
#
# Generated text on step 1600:
#
#
# sports
# Which team won the first ever Super Bowl? (The New York Giants)
#
#
# celebrities
# In what year did the first movie starring John Travolta hit theatres? (1954)
#
#
# history
# The first atomic bomb was dropped on Hiroshima, Japan in 1945. (False)
#
#
# Generated text on step 1650:
#
#
# general
# What is the name of a character in which Harry Potter and Ron Weasley meet? (The Headmaster)
#
#
# history
# What was the name of a fictional character who lived in Paris during World War II? (Theodore)
#
#
# history
# The Battle of the Bulge, which started on June 1st 1942 in what year? (1942)
#
#
# Generated text on step 1700:
#
#
# religion
# In the Bible, what is a woman called? (A widow)
#
#
# sports
# In what year did the New York Yankees win their first World Series title? (1962)
#
#
# geography
# What is the largest city in Romania? (Roma)
#
#
# Generated text on step 1750:
#
#
# music
# Which of the following was not a member or co-founder in The Beatles? (John Lennon)
#
#
# linguistics
# The term  mensa means a man who is not married. (False)
#
#
# sports
# Which of the following is not a nickname for former NBA player and current ESPN analyst, Joe Lunardi? (The Man)
#
#
# Generated text on step 1800:
#
#
# sports
# What is the name of a team that was known as The Yankees? (The Bronx Bombers)
#
#
# literature
# What is the title of a novel by William Faulkner? (The Silver Chair)
#
#
# brain teasers
# What is the name of a character in which Harry Potter and Hermione Granger meet? (Professor Snape)
#
#
# Generated text on step 1850:
#
#
# sports
# This player was the first to hit a home run in his career. (Buddy Hield)
#
#
# general
# What is the name of a fictional character in which Harry Potter and Hermione Granger are characters? (Hermione)
#
#
# animals
# What is the gestation period of a panda? (12-14 days)
#
#
# Generated text on step 1900:
#
#
# music
# Which of the following is not a song by The Beatles? (A Day in Heaven)
#
#
# religion
# What is the name of Jesus son in Matthew? (Jude)
#
#
# general
# What is the name of a character in which Harry Potter and Ron Weasley are characters? (Dumbledore)
#
#
# Generated text on step 1950:
#
#
# video games
# In the game Super Smash Bros. Brawl, what is a character called? (A fighter)
#
#
# movies
# What is the name of Marni Nixons character in The Godfather? (Marlena)
#
#
# geography
# Which of the following is not a city in which there are no more than two major roads? (New York City)
#
#
# Generated text on step 2000:
#
#
# linguistics
# Which of the following is not a word in which there are no vowels? (noun)
#
#
# sports
# What is the name of a fictional character from which The Princess Bride was based? (The Prince)
#
#
# music
# Which song by The Beatles was written for the soundtrack to a movie? (Help!)
#
#
# Generated text on step 2050:
#
#
# animals
# The Japanese tiger is the largest of all living animals. (True)
#
#
# religion
# In what year did the first mass wedding ceremony take place in Jerusalem? (19th century)
#
#
# sports
# What is the nickname of baseball player, who was born in New York City? (Babe Ruth)
#
#
# Generated text on step 2100:
#
#
# history
# Which of the following is not a character from Harry Potter and The Prisoner? (Draco Malfoy)
#
#
# celebrities
# What was the name of John Wayne character in The Last Dragon? (Theodore)
#
#
# science
# What is the name of a type that contains only one or two atoms? (Higgs)
#
#
# Epoch 4
# Learning Rate: 3.508333333333334e-05
# Generated text on step 2150:
#
#
# science
# What is the name of a type in which all objects are equal? (Equal)
#
#
# television
# What is the name of The Simpsons character who has a crush on Lisa? (Marge Simpson)
#
#
# religion
# What is the name of a group that was banned in India from 1857 to 1860? (The Hindu Order)
#
#
# Generated text on step 2200:
#
#
# celebrities
# What is the name of this movie about a group that fights for freedom in Cuba? (The Cuban Missile Crisis)
#
#
# television
# What is the name of The Simpsons character Bart Simpson? (The King)
#
#
# science
# What is the name of a type-2 diabetes mellitus, characterized by progressive weight loss? (Metabolic syndrome)
#
#
# Generated text on step 2250:
#
#
# history
# Which of the following is not a member's name? (John McCain)
#
#
# movies
# In the movie The Pursuit of Happyness, what is a character named Jacksons name? (Jack)
#
#
# geography
# Which of the following is not a country in Africa? (Cameroon)
#
#
# Generated text on step 2300:
#
#
# literature
# In the book The Da Vinci Code, what is a da vincium? (A device that produces light)
#
#
# religion
# What is the name of a book by Rabbi Abraham Joshua Heschel? (The Book Of The Dead)
#
#
# linguistics
# What is the meaning of this word? (A person who has a strong will)
#
#
# Generated text on step 2350:
#
#
# brain teasers
# What is the name of a character in The Lion, Wushu? (The Great)
#
#
# linguistics
# Which is the correct translation of this proverb: A man who has a dream, but doesnt have an opportunity? (A fool)
#
#
# music
# This singer had a #1 hit in the U.S with The Way You Love Me? (Paula)
#
#
# Generated text on step 2400:
#
#
# history
# What was the name of King Arthur? (Arthur)
#
#
# religion
# What is the name of Jesus son, who was crucified on April 15th? (John)
#
#
# sports
# Which team won the first NBA Championship in 2000? (The Los Angeles Lakers)
#
#
# Generated text on step 2450:
#
#
# video games
# In the game RuneScape, you can use a pickax to get around in which way? (By jumping)
#
#
# movies
# In the movie The Graduate, what was a professor doing in class? (Reading)
#
#
# linguistics
# What is the name of a typeface used in print? (Lucida)
#
#
# Generated text on step 2500:
#
#
# linguistics
# What is the meaning of this word: a person who has an interest in what? (A subject)
#
#
# sports
# What is the name of baseball player who hit a home run in his first at bat? (Joe Morgan)
#
#
# video games
# In the game RuneScape, you can use which of these items? (Potion)
#
#
# Generated text on step 2550:
#
#
# general
# What is the name of a famous movie about an American soldier who was wounded in Vietnam? (The Longest Day)
#
#
# geography
# Which of the following is a type in which there are no two? (Paleozoic)
#
#
# general
# What is the name of a character in which Harry Potter and Ron Weasley have an affair? (Hermione)
#
#
# Generated text on step 2600:
#
#
# religion
# Which is the correct translation of Hebrews phrase, I am a stranger in your land? (I have no land)
#
#
# music
# This singer had a #1 hit in 1977 with the song I Want You to Know. (Barry White)
#
#
# animals
# What is the average lifespan of a platypus? (10 years)
#
#
# Generated text on step 2650:
#
#
# animals
# What is the average lifespan of a tiger shark? (10 years)
#
#
# geography
# Which of the following is not a capital city in India? (New Delhi)
#
#
# music
# What is the name of this group, formed in 1975? (The Beatles)
#
#
# Generated text on step 2700:
#
#
# brain teasers
# A dog walks into a room and sees what? (a woman with her hair in braids)
#
#
# movies
# What is the name of The Big Lebowski character in which movie? (Leopold)
#
#
# linguistics
# The word ichthyology is related to which of these? (the study and classification)
#
#
# Generated text on step 2750:
#
#
# brain teasers
# What is the missing word in this proverb: A man who has a good heart will have an even better mind.? (Athletics)
#
#
# movies
# In the movie The Godfather, what is a man called? (A mobster)
#
#
# history
# In what year was the first commercial use of a mobile telephone in Europe? (1908)
#
#
# Generated text on step 2800:
#
#
# religion
# What is the name of Jesus son according to Jewish tradition? (Joseph)
#
#
# general
# What is the name of a popular American sitcom that ran from 1964 to 1969? (The Honeymooners)
#
#
# animals
# What is the average lifespan of a pangolin? (10 years)
#
#
# Epoch 5
# Learning Rate: 4.681666666666667e-05
# Generated text on step 2850:
#
#
# video games
# What is the name of a character in Super Smash Bros Brawl? (Mr. Mario)
#
#
# literature
# What is the name of Harry Potters friend in The Dark Tower series? (Ron)
#
#
# science
# What is the name of a type that can be found in nature? (Coral Reef)
#
#
# Generated text on step 2900:
#
#
# television
# What is the name of The Man from Ugly Betty? (Tommy)
#
#
# celebrities
# What is the name of actor and director John Travolta? (John Wayne)
#
#
# literature
# In the novel The Amber Spyglass, what is a spy? (A person who works for an enemy)
#
#
# Generated text on step 2950:
#
#
# general
# What is the name of a character in The Lord Of Flies who was bitten by an eagle? (Gwynne)
#
#
# sports
# Which of the following is not a nickname for Major League Baseball? (The Little Leaguer)
#
#
# general
# What is the name of a group that performs in New York City? (The Cardigans)
#
#
# Generated text on step 3000:
#
#
# science
# What is the name of a type in chemistry that consists mainly or entirely (in part)  hydrogen?
#
#
# sports
# What is the nickname of LSU? (The Tigers)
#
#
# movies
# In the movie The Passion of _________. (The Phantom)
#
#
# Generated text on step 3050:
#
#
# brain teasers
# The first time I saw a man, he was in the middle of nowhere.  He said to me: “I dont know where this is” (in my mind)
#
#
# literature
# What is the name of Harry Potters father in The Goblet Of Fire? (George)
#
#
# movies
# What is the name of a character in The Lost Boys, who was played by actress Debra Winger? (Diane)
#
#
# Generated text on step 3100:
#
#
# movies
# What was the name of Dylans first love interest in The Goonies? (Cindy)
#
#
# brain teasers
# What is the name of a type in which two or more consecutive numbers are joined together? (Triangle)
#
#
# video games
# What is the name of Links first pet in The Legend Of Zelda series? (Ocarina)
#
#
# Generated text on step 3150:
#
#
# animals
# What is the average lifespan of a wild cat? (10-15 years)
#
#
# geography
# Which is the capital of Switzerland? (Bern)
#
#
# animals
# What is the average lifespan of a giraffe? (40 years)
#
#
# Generated text on step 3200:
#
#
# celebrities
# What is the name of George Washingtons first-born son? (George)
#
#
# television
# What is the name of The Simpsons character who has a pet monkey named Munchkin? (Milo)
#
#
# sports
# This former NBA player, who played with the Boston Celtics and the New York Knicks in his career is considered one of The Greatest NBA Players. (Hakeem Olajuwon)
#
#
# Generated text on step 3250:
#
#
# music
# The song The Night the Lights Went Out in Georgia was a hit for this singer, who died of an overdose. (Barry Manilow)
#
#
# literature
# What is the name of Harry Potters best friend in The Goblet of Fire? (Ron)
#
#
# sports
# What was the first name of Yogi Berra? (Yogi)
#
#
# Generated text on step 3300:
#
#
# linguistics
# Which is the correct name of a type, characterized by its characteristic shape and color? (Cerulean)
#
#
# animals
# What is the average lifespan of a crocodilian? (40 years)
#
#
# science
# What is the name of a type that occurs naturally in plants? (Cultivation)
#
#
# Generated text on step 3350:
#
#
# geography
# What is the capital of South Carolina? (Charleston)
#
#
# science
# What is the name of a type-1 diabetes drug that treats only one or two types? (Tegenor)
#
#
# sports
# Which of the following players has not played in at least 200 games? (Barry Bonds)
#
#
# Generated text on step 3400:
#
#
# history
# Which of the following was not a member or former president? (George Washington)
#
#
# literature
# What is the name of Tom Cruises character in The Phantom Menace? (Tom Cruise)
#
#
# geography
# What is the largest island in South America? (Antarctica)
#
#
# Generated text on step 3450:
#
#
# movies
# What is the name of James Bonds character in Goldfinger? (Dr. No)
#
#
# general
# What is the name of a character in The Wizard Of Oz? (The Scarecrow)
#
#
# video games
# What is the name of Samus Aran in Metroid: Other M? (Samuel)
#
#
# Generated text on step 3500:
#
#
# television
# What was the name of The Big Bang Theory character who had a crush on Rachel? (Boris)
#
#
# music
# What was the name of The Beatles first album? (Hey Jude)
#
#
# linguistics
# What is the meaning of “the” word in Spanish? (a person)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     849         with _open_zipfile_writer(f) as opened_zipfile:
# --> 850             _save(
#     851                 obj,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1113             # Now that it is on the CPU we can directly copy it into the zip file
# -> 1114             zip_file.write_record(name, storage, num_bytes)
#    1115
#
# RuntimeError: [enforce fail at inline_container.cc:778] . PytorchStreamWriter failed writing file data/56: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_31/279672313.py in <cell line: 0>()
#      77
#      78 # start fine tuning
# ---> 79 trainer.train()
#      80
#      81 # save the fine tuned model
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243                 hf_hub_utils.enable_progress_bars()
#    2244         else:
# -> 2245             return inner_training_loop(
#    2246                 args=args,
#    2247                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2659
#    2660             self.control = self.callback_handler.on_epoch_end(args, self.state, self.control)
# -> 2661             self._maybe_log_save_evaluate(
#    2662                 tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time, learning_rate=learning_rate
#    2663             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time, learning_rate)
#    3101
#    3102         if self.control.should_save:
# -> 3103             self._save_checkpoint(model, trial)
#    3104             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    3105
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _save_checkpoint(self, model, trial)
#    3209         if not self.args.save_only_model:
#    3210             # Save optimizer and scheduler
# -> 3211             self._save_optimizer_and_scheduler(output_dir)
#    3212             self._save_scaler(output_dir)
#    3213             # Save RNG state
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _save_optimizer_and_scheduler(self, output_dir)
#    3337         elif self.args.should_save:
#    3338             # deepspeed.save_checkpoint above saves model/optim/sched
# -> 3339             torch.save(self.optimizer.state_dict(), os.path.join(output_dir, OPTIMIZER_NAME))
#    3340
#    3341         # Save SCHEDULER & SCALER
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     847
#     848     if _use_new_zipfile_serialization:
# --> 849         with _open_zipfile_writer(f) as opened_zipfile:
#     850             _save(
#     851                 obj,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in __exit__(self, *args)
#     688
#     689     def __exit__(self, *args) -> None:
# --> 690         self.file_like.write_end_of_file()
#     691         if self.file_stream is not None:
#     692             self.file_stream.close()
#
# RuntimeError: [enforce fail at inline_container.cc:603] . unexpected pos 2455647744 vs 2455647632
